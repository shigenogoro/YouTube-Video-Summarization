# %% [markdown]
# # Data Exploration
#
# This notebooks is used to setup the environment and explored the `MeetingBank` dataset
#
# - Github setup
#
# - Install Packages
#
# - Load Data
#
# - Observe the example

# %% [markdown]
# ## Github Setup

# %%
username = 'shigenogoro'
repo_name = 'YouTube-Video-Summarization'
branch = 'kyle'

# Clone the repository 
# !git clone https://github.com/{username}/{repo_name}.git -b {branch}

# Change directory to the cloned repository
# %cd {repo_name}

# %%
# Pull the latest changes
# !git pull origin {branch}
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7 (delta 4), reused 7 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 568 bytes | 189.00 KiB/s, done.
# From https://github.com/shigenogoro/YouTube-Video-Summarization
#  * branch            kyle       -> FETCH_HEAD
#    1d5e182..9214b35  kyle       -> origin/kyle
# Updating 1d5e182..9214b35
# Fast-forward
#  .../phase1_meetingBank/01_data_exploration.ipynb   | 233 +--------------------
#  src/data_loader.py                                 |   3 -
#  2 files changed, 10 insertions(+), 226 deletions(-)

# %% [markdown]
# ## Packages Setup

# %%
# !pip install -r requirements.txt

# %%
# Download NLTK resources

# !python -m spacy download en_core_web_sm

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# %% [markdown]
# ## Load Data

# %%
from datasets import load_dataset

meetingbank = load_dataset("huuuyeah/meetingbank")

# Print the shape of the datasets
print(f"Train data shape: {meetingbank['train'].shape}")
print(f"Validation data shape: {meetingbank['validation'].shape}")
print(f"Test data shape: {meetingbank['test'].shape}")
# Out:
# Train data shape: (5169, 4)
# Validation data shape: (861, 4)
# Test data shape: (862, 4)

# %% [markdown]
# ## Data Observation

# %%
# Store the datasets into dataframes
import pandas as pd

train_df = pd.DataFrame(meetingbank['train'])
val_df = pd.DataFrame(meetingbank['validation'])
test_df = pd.DataFrame(meetingbank['test'])

# Display the first few rows of the training dataframe
train_df.head(1)
# Out:
#                                              summary  \
# 0  AS AMENDED a bill for an ordinance amending th...
#
#                                   uid  id  \
# 0  DenverCityCouncil_05012017_17-0161   0
#
#                                           transcript
# 0  Please refrain from profane or obscene speech....
